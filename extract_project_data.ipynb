# %%
import pandas as pd

# %%
df = pd.read_csv("raw_data/projects_data.csv")
df
# Out:
# C:\Users\dzikri\AppData\Local\Temp\ipykernel_30472\2965136853.py:1: DtypeWarning: Columns (44) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("projects_data.csv")
#             id                   regionname  \
# 0      P162228                        Other
# 1      P163962                       Africa
# 2      P167672                   South Asia
# 3      P158768                   South Asia
# 4      P161364                       Africa
# ...        ...                          ...
# 18243  P006578  Latin America and Caribbean
# 18244  P037451      Europe and Central Asia
# 18245  P037362      Europe and Central Asia
# 18246  P037452      Europe and Central Asia
# 18247  P037383      Europe and Central Asia
#
#                                              countryname prodline  \
# 0                                            World;World       RE
# 1      Democratic Republic of the Congo;Democratic Re...       PE
# ...

# %%
# Menghitung jumlah data yang hilang sebelum dihapus
missing_data_count = df.isnull().sum()
print("Jumlah data yang hilang sebelum dihapus:")
missing_data_count
# Out:
# Jumlah data yang hilang sebelum dihapus:
# id                              0
# regionname                      0
# countryname                     0
# prodline                        0
# lendinginstr                  246
# lendinginstrtype              246
# envassesmentcategorycode     5811
# supplementprojectflg           53
# productlinetype                 0
# projectstatusdisplay            4
# status                          4
# project_name                    0
# boardapprovaldate            1504
# board_approval_month         1504
# closingdate                  3349
# lendprojectcost               125
# ibrdcommamt                     0
# idacommamt                      0
# totalamt                        0
# grantamt                        0
# borrower                     5919
# impagency                    6097
# url                             0
# projectdoc                  18248
# majorsector_percent         18248
# sector1                         0
# ...

# %%
# Menghitung jumlah data duplikat sebelum dihapus
duplicate_data_count = df.duplicated().sum()
print("Jumlah data duplikat sebelum dihapus:", duplicate_data_count)
# Out:
# Jumlah data duplikat sebelum dihapus: 0

# %%
# Mengatasi data yang hilang
data_project_missing = df.dropna()
print("Data yang hilang telah dihapus.")
print (data_project_missing)
# Out:
# Data yang hilang telah dihapus.
# Empty DataFrame
# Columns: [id, regionname, countryname, prodline, lendinginstr, lendinginstrtype, envassesmentcategorycode, supplementprojectflg, productlinetype, projectstatusdisplay, status, project_name, boardapprovaldate, board_approval_month, closingdate, lendprojectcost, ibrdcommamt, idacommamt, totalamt, grantamt, borrower, impagency, url, projectdoc , majorsector_percent , sector1, sector2, sector3, sector4, sector5, sector, mjsector1, mjsector2, mjsector3, mjsector4, mjsector5, mjsector, theme1, theme2, theme3, theme4, theme5, theme , goal, financier, mjtheme1name, mjtheme2name, mjtheme3name, mjtheme4name, mjtheme5name, location, GeoLocID, GeoLocName, Latitude, Longitude, Country, Unnamed: 56]
# Index: []
#
# [0 rows x 57 columns]

# %%
# Menghapus data duplikat
data_project_duplikat = df.drop_duplicates()
print("Data duplikat telah dihapus.")
print(data_project_duplikat)
# Out:
# Data duplikat telah dihapus.
#             id                   regionname  \
# 0      P162228                        Other
# 1      P163962                       Africa
# 2      P167672                   South Asia
# 3      P158768                   South Asia
# 4      P161364                       Africa
# ...        ...                          ...
# 18243  P006578  Latin America and Caribbean
# 18244  P037451      Europe and Central Asia
# 18245  P037362      Europe and Central Asia
# 18246  P037452      Europe and Central Asia
# 18247  P037383      Europe and Central Asia
#
#                                              countryname prodline  \
# 0                                            World;World       RE
# 1      Democratic Republic of the Congo;Democratic Re...       PE
# 2      People's Republic of Bangladesh;People's Repub...       PE
# 3      Islamic  Republic of Afghanistan;Islamic  Repu...       PE
# 4      Federal Republic of Nigeria;Federal Republic o...       PE
# ...
